# %% [markdown]
# #Installazione Librerie

# %%
# !pip install tensorflow==1.15.4 google-api-python-client oauth2client tqdm numpy pandas==0.25.3 torch===1.4.0 allennlp
# Out:
# ...
#      |████████████████████████████████| 110.5 MB 17 kB/s
# ...
#      |████████████████████████████████| 10.4 MB 56.7 MB/s
# ...
#      |████████████████████████████████| 753.4 MB 4.3 kB/s
# ...
#      |████████████████████████████████| 689 kB 30.1 MB/s
# ...
#      |████████████████████████████████| 20.1 MB 1.7 MB/s
# ...
#      |████████████████████████████████| 503 kB 73.6 MB/s
# ...
#      |████████████████████████████████| 3.8 MB 22.2 MB/s
# ...
#      |████████████████████████████████| 50 kB 5.9 MB/s
# ...
#      |████████████████████████████████| 131 kB 57.7 MB/s
# ...
#      |████████████████████████████████| 1.8 MB 41.8 MB/s
# ...
#      |████████████████████████████████| 259 kB 53.4 MB/s
# ...
#      |████████████████████████████████| 43 kB 1.7 MB/s
# ...
#      |████████████████████████████████| 124 kB 49.9 MB/s
# ...
#      |████████████████████████████████| 12.1 MB 220 kB/s
# ...
#      |████████████████████████████████| 105 kB 56.0 MB/s
# ...
#      |████████████████████████████████| 2.5 MB 27.0 MB/s
# ...

# %%
# !pip install bert
# !cp /content/drive/MyDrive/BioCreative/bluebert/bert/* /usr/local/lib/python3.7/dist-packages/bert
# !ls /usr/local/lib/python3.7/dist-packages/bert
# Out:
# ...
#   Created wheel for bert: filename=bert-2.2.0-py3-none-any.whl size=3767 sha256=37d6dd9bf30ca2c3ced623a281930fd7a01c459696f4dea6b3b76d801206c6a7
#   Stored in directory: /root/.cache/pip/wheels/bb/31/1b/c05f362e347429b7436954d1a2280fe464731e8f569123a848
# ...
#   Created wheel for erlastic: filename=erlastic-2.0.0-py3-none-any.whl size=6794 sha256=6b43f308f14a286b58ba0a628211683d90987aef393e3c459b42e3d1a9b0d437
#   Stored in directory: /root/.cache/pip/wheels/94/f1/b4/0b98b1e94775da6a0b1130e342d22af05cd269e1172c19f40f
# Successfully built bert erlastic
# ...
# codec.py		    modeling.py		  run_classifier.py
# CONTRIBUTING.md		    modeling_test.py	  run_pretraining.py
# create_pretraining_data.py  multilingual.md	  run_squad.py
# download_glue_data.py	    optimization.py	  sample_text.txt
# extract_features.py	    optimization_test.py  tokenization.py
# __init__.py		    __pycache__		  tokenization_test.py
# LICENSE			    README.md

# %% [markdown]
# # Esecuzione

# %%
import tensorflow
print(tensorflow.distribute.cluster_resolver.TPUClusterResolver().cluster_spec().as_dict()["worker"][0])
# TPU ADDRESS
# Out:
# 10.18.18.2:8470

# %%
# !cd /content/drive/MyDrive/BioCreative;\
python bluebert/bluebert/run_bluebert.py --do_train=true --do_eval=false --do_predict=true --task_name="chemprot2" \
--vocab_file=bluebert/vocab.txt --bert_config_file=bluebert/bert_config.json --init_checkpoint=bluebert/bert_model.ckpt \
--num_train_epochs=2.0 --data_dir=. --output_dir=output --do_lower_case=true
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/bert/optimization.py:87: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From bluebert/bluebert/run_bluebert.py:762: The name tf.app.run is deprecated. Please use tf.compat.v1.app.run instead.
#
# WARNING:tensorflow:From bluebert/bluebert/run_bluebert.py:600: The name tf.logging.set_verbosity is deprecated. Please use tf.compat.v1.logging.set_verbosity instead.
#
# W0807 11:24:40.233761 140539479639936 module_wrapper.py:139] From bluebert/bluebert/run_bluebert.py:600: The name tf.logging.set_verbosity is deprecated. Please use tf.compat.v1.logging.set_verbosity instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/bert/modeling.py:92: The name tf.gfile.GFile is deprecated. Please use tf.io.gfile.GFile instead.
#
# ...
